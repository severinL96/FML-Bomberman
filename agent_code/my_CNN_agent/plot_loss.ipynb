# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

loss = pd.read_csv("saved_models/CNN_first_try/loss.txt",header=None)
epoch_count = range(1 ,len(loss)+1)


#losses = losses[-1000:]
#epoch_count = epoch_count[-1000:]
plt.figure(figsize=(8,5))
plt.xlabel('# epochs trained',  fontsize=15)
plt.ylabel('Loss',  fontsize=15)
plt.plot(epoch_count, loss)
#plt.plot(epoch_count,  new_y)
plt.grid(True,  which="both")
plt.title('loss CNN - simple architecture')
#plt.yscale('log')
#plt.ylim((0 ,5))
plt.Figure()
plt.savefig('the_agent_gets_stuck_in_a_bad_local_minimum.png')

# %%
loss = pd.read_csv("saved_models/CNN_first_try/average_reward.txt",header=None)
epoch_count = range(1 ,len(loss)+1)


#losses = losses[-1000:]
#epoch_count = epoch_count[-1000:]
plt.figure(figsize=(8,5))
plt.xlabel('round e',  fontsize=15)
plt.ylabel('average reward per move',  fontsize=15)
plt.plot(epoch_count, loss)
plt.grid(True,  which="both")
plt.title('average reward per round')
plt.Figure()
plt.savefig('the_agent_gets_stuck_in_a_bad_local_minimum.png')
