# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

loss = pd.read_csv("saved_models/CNN_first_try/loss.txt",header=None)
epoch_count = range(1 ,len(loss)+1)


#losses = losses[-1000:]
#epoch_count = epoch_count[-1000:]
plt.figure(figsize=(8,5))
plt.xlabel('# epochs trained',  fontsize=15)
plt.ylabel('Loss',  fontsize=15)
plt.plot(epoch_count, loss)
#plt.plot(epoch_count,  new_y)
plt.grid(True,  which="both")
plt.title('loss CNN - simple architecture')
#plt.yscale('log')
#plt.ylim((0 ,5))
plt.Figure()
plt.savefig('the_agent_gets_stuck_in_a_bad_local_minimum.png')

# %%
game_length = pd.read_csv("saved_models/CNN_first_try/game_length.txt",header=None)
step_reward = pd.read_csv("saved_models/CNN_first_try/step_reward.txt",header=None)

epoch_count = range(1 ,len(game_length)+1)


fig = plt.figure()
ax1 = fig.add_subplot(111)
plt.plot(epoch_count, game_length,'k')
ax1.set_ylabel('game length')
ax1.set_xlabel('epoch e')
ax1.grid(True,which = 'both')

ax2 = ax1.twinx()
plt.plot(epoch_count, step_reward,'r-')
ax2.set_ylabel('average reward per step', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')
plt.title("Total Game reward and average reward per step")
# Out:
# Text(0.5, 1.0, 'Total Game reward and average reward per step')
